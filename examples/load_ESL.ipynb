# %%
from ml_datasets.esl import Mixture
from ml_datasets.utils import plot_2D

# %%
mixture = Mixture(verbose=False)
x, y = mixture.load()

# %%
print("x: {}, y: {}".format(x.shape, y.shape))
# Out:
# x: (200, 2), y: (200,)

# %%
plot_2D(x, y, "ESL-Mixture Dataset")
